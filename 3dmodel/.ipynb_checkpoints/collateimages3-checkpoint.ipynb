# %%
import time
import sys
import glob
import numpy as np
import skimage as sk
from PIL import Image

# path for image corpus
pathCoronal = '../../Zanabazar/CORONAL/*.*';
pathSagittal = '../../Zanabazar/SAGITTAL/*.*';
pathHorizon = '../../Zanabazar/HORIZON/*.*';
directionForward = False;
path = pathSagittal;

# variables
image3D = [];                 # container for 3D image data
background = None;            # background image data for ghetto paste render
transparencyThreshold = 5;    # threshold for setting transparent values

images = glob.glob(path);     # get all images in the folder
if not directionForward:
    print "Iterating backwards";
    images.reverse();
for index, image in enumerate(images):  # iterate through all images in folder
    print 'Processing image #' + str(index) + ": " + image;
    img = Image.open(image);   # open the image
    img = img.convert("RGBA"); # convert image to RGBA format
    if not background:         # if background doesn't exist
        background = img;      # use first image
    pixels = img.getdata();    # get pixel data

    # iterate through all pixel data
    newPixels = [];
    for rgb in pixels:
        mean = (rgb[0] + rgb[1] + rgb[2]) / 3;
        # if pixel value less than threshold
        if mean <= transparencyThreshold: 
            newPixels.append((0, 0, 0, 0));  # make transparent
        else: # otherwise use the value, but make it more transparent the closer to black
            newPixels.append((rgb[0], rgb[1], rgb[2], int(mean)));
        
    img.putdata(newPixels);
    if background != img:
        background.paste(img, (0, 0), img);
        
background.show();
background.save("posterior zbar.png", "PNG");
# Out:
# Iterating backwards
# Processing image #0: ../../Zanabazar/SAGITTAL/SAG184.TIF
# Processing image #1: ../../Zanabazar/SAGITTAL/SAG183.TIF
# Processing image #2: ../../Zanabazar/SAGITTAL/SAG182.TIF
# Processing image #3: ../../Zanabazar/SAGITTAL/SAG181.TIF
# Processing image #4: ../../Zanabazar/SAGITTAL/SAG180.TIF
# Processing image #5: ../../Zanabazar/SAGITTAL/SAG179.TIF
# Processing image #6: ../../Zanabazar/SAGITTAL/SAG178.TIF
# Processing image #7: ../../Zanabazar/SAGITTAL/SAG177.TIF
# Processing image #8: ../../Zanabazar/SAGITTAL/SAG176.TIF
# Processing image #9: ../../Zanabazar/SAGITTAL/SAG175.TIF
# Processing image #10: ../../Zanabazar/SAGITTAL/SAG174.TIF
# Processing image #11: ../../Zanabazar/SAGITTAL/SAG173.TIF
# Processing image #12: ../../Zanabazar/SAGITTAL/SAG172.TIF
# Processing image #13: ../../Zanabazar/SAGITTAL/SAG171.TIF
# Processing image #14: ../../Zanabazar/SAGITTAL/SAG170.TIF
# Processing image #15: ../../Zanabazar/SAGITTAL/SAG169.TIF
# Processing image #16: ../../Zanabazar/SAGITTAL/SAG168.TIF
# Processing image #17: ../../Zanabazar/SAGITTAL/SAG167.TIF
# Processing image #18: ../../Zanabazar/SAGITTAL/SAG166.TIF
# Processing image #19: ../../Zanabazar/SAGITTAL/SAG165.TIF
# Processing image #20: ../../Zanabazar/SAGITTAL/SAG164.TIF
# Processing image #21: ../../Zanabazar/SAGITTAL/SAG163.TIF
# Processing image #22: ../../Zanabazar/SAGITTAL/SAG162.TIF
# Processing image #23: ../../Zanabazar/SAGITTAL/SAG161.TIF
# Processing image #24: ../../Zanabazar/SAGITTAL/SAG160.TIF
# Processing image #25: ../../Zanabazar/SAGITTAL/SAG159.TIF
# Processing image #26: ../../Zanabazar/SAGITTAL/SAG158.TIF
# Processing image #27: ../../Zanabazar/SAGITTAL/SAG157.TIF
# Processing image #28: ../../Zanabazar/SAGITTAL/SAG156.TIF
# Processing image #29: ../../Zanabazar/SAGITTAL/SAG155.TIF
# Processing image #30: ../../Zanabazar/SAGITTAL/SAG154.TIF
# Processing image #31: ../../Zanabazar/SAGITTAL/SAG153.TIF
# Processing image #32: ../../Zanabazar/SAGITTAL/SAG152.TIF
# Processing image #33: ../../Zanabazar/SAGITTAL/SAG151.TIF
# Processing image #34: ../../Zanabazar/SAGITTAL/SAG150.TIF
# Processing image #35: ../../Zanabazar/SAGITTAL/SAG149.TIF
# Processing image #36: ../../Zanabazar/SAGITTAL/SAG148.TIF
# Processing image #37: ../../Zanabazar/SAGITTAL/SAG147.TIF
# Processing image #38: ../../Zanabazar/SAGITTAL/SAG146.TIF
# Processing image #39: ../../Zanabazar/SAGITTAL/SAG145.TIF
# Processing image #40: ../../Zanabazar/SAGITTAL/SAG144.TIF
# Processing image #41: ../../Zanabazar/SAGITTAL/SAG143.TIF
# Processing image #42: ../../Zanabazar/SAGITTAL/SAG142.TIF
# Processing image #43: ../../Zanabazar/SAGITTAL/SAG141.TIF
# Processing image #44: ../../Zanabazar/SAGITTAL/SAG140.TIF
# Processing image #45: ../../Zanabazar/SAGITTAL/SAG139.TIF
# Processing image #46: ../../Zanabazar/SAGITTAL/SAG138.TIF
# Processing image #47: ../../Zanabazar/SAGITTAL/SAG137.TIF
# Processing image #48: ../../Zanabazar/SAGITTAL/SAG136.TIF
# Processing image #49: ../../Zanabazar/SAGITTAL/SAG135.TIF
# Processing image #50: ../../Zanabazar/SAGITTAL/SAG134.TIF
# Processing image #51: ../../Zanabazar/SAGITTAL/SAG133.TIF
# Processing image #52: ../../Zanabazar/SAGITTAL/SAG132.TIF
# Processing image #53: ../../Zanabazar/SAGITTAL/SAG131.TIF
# Processing image #54: ../../Zanabazar/SAGITTAL/SAG130.TIF
# Processing image #55: ../../Zanabazar/SAGITTAL/SAG129.TIF
# Processing image #56: ../../Zanabazar/SAGITTAL/SAG128.TIF
# Processing image #57: ../../Zanabazar/SAGITTAL/SAG127.TIF
# Processing image #58: ../../Zanabazar/SAGITTAL/SAG126.TIF
# Processing image #59: ../../Zanabazar/SAGITTAL/SAG125.TIF
# Processing image #60: ../../Zanabazar/SAGITTAL/SAG124.TIF
# Processing image #61: ../../Zanabazar/SAGITTAL/SAG123.TIF
# Processing image #62: ../../Zanabazar/SAGITTAL/SAG122.TIF
# Processing image #63: ../../Zanabazar/SAGITTAL/SAG121.TIF
# Processing image #64: ../../Zanabazar/SAGITTAL/SAG120.TIF
# Processing image #65: ../../Zanabazar/SAGITTAL/SAG119.TIF
# Processing image #66: ../../Zanabazar/SAGITTAL/SAG118.TIF
# Processing image #67: ../../Zanabazar/SAGITTAL/SAG117.TIF
# Processing image #68: ../../Zanabazar/SAGITTAL/SAG116.TIF
# Processing image #69: ../../Zanabazar/SAGITTAL/SAG115.TIF
# Processing image #70: ../../Zanabazar/SAGITTAL/SAG114.TIF
# Processing image #71: ../../Zanabazar/SAGITTAL/SAG113.TIF
# Processing image #72: ../../Zanabazar/SAGITTAL/SAG112.TIF
# Processing image #73: ../../Zanabazar/SAGITTAL/SAG111.TIF
# Processing image #74: ../../Zanabazar/SAGITTAL/SAG110.TIF
# Processing image #75: ../../Zanabazar/SAGITTAL/SAG109.TIF
# Processing image #76: ../../Zanabazar/SAGITTAL/SAG108.TIF
# Processing image #77: ../../Zanabazar/SAGITTAL/SAG107.TIF
# Processing image #78: ../../Zanabazar/SAGITTAL/SAG106.TIF
# Processing image #79: ../../Zanabazar/SAGITTAL/SAG105.TIF
# Processing image #80: ../../Zanabazar/SAGITTAL/SAG104.TIF
# Processing image #81: ../../Zanabazar/SAGITTAL/SAG103.TIF
# Processing image #82: ../../Zanabazar/SAGITTAL/SAG102.TIF
# Processing image #83: ../../Zanabazar/SAGITTAL/SAG101.TIF
# Processing image #84: ../../Zanabazar/SAGITTAL/SAG100.TIF
# Processing image #85: ../../Zanabazar/SAGITTAL/SAG099.TIF
# Processing image #86: ../../Zanabazar/SAGITTAL/SAG098.TIF
# Processing image #87: ../../Zanabazar/SAGITTAL/SAG097.TIF
# Processing image #88: ../../Zanabazar/SAGITTAL/SAG096.TIF
# Processing image #89: ../../Zanabazar/SAGITTAL/SAG095.TIF
# Processing image #90: ../../Zanabazar/SAGITTAL/SAG094.TIF
# Processing image #91: ../../Zanabazar/SAGITTAL/SAG093.TIF
# Processing image #92: ../../Zanabazar/SAGITTAL/SAG092.TIF
# Processing image #93: ../../Zanabazar/SAGITTAL/SAG091.TIF
# Processing image #94: ../../Zanabazar/SAGITTAL/SAG090.TIF
# Processing image #95: ../../Zanabazar/SAGITTAL/SAG089.TIF
# Processing image #96: ../../Zanabazar/SAGITTAL/SAG088.TIF
# Processing image #97: ../../Zanabazar/SAGITTAL/SAG087.TIF
# Processing image #98: ../../Zanabazar/SAGITTAL/SAG086.TIF
# Processing image #99: ../../Zanabazar/SAGITTAL/SAG085.TIF
# Processing image #100: ../../Zanabazar/SAGITTAL/SAG084.TIF
# Processing image #101: ../../Zanabazar/SAGITTAL/SAG083.TIF
# Processing image #102: ../../Zanabazar/SAGITTAL/SAG082.TIF
# Processing image #103: ../../Zanabazar/SAGITTAL/SAG081.TIF
# Processing image #104: ../../Zanabazar/SAGITTAL/SAG080.TIF
# Processing image #105: ../../Zanabazar/SAGITTAL/SAG079.TIF
# Processing image #106: ../../Zanabazar/SAGITTAL/SAG078.TIF
# Processing image #107: ../../Zanabazar/SAGITTAL/SAG077.TIF
# Processing image #108: ../../Zanabazar/SAGITTAL/SAG076.TIF
# Processing image #109: ../../Zanabazar/SAGITTAL/SAG075.TIF
# Processing image #110: ../../Zanabazar/SAGITTAL/SAG074.TIF
# Processing image #111: ../../Zanabazar/SAGITTAL/SAG073.TIF
# Processing image #112: ../../Zanabazar/SAGITTAL/SAG072.TIF
# Processing image #113: ../../Zanabazar/SAGITTAL/SAG071.TIF
# Processing image #114: ../../Zanabazar/SAGITTAL/SAG070.TIF
# Processing image #115: ../../Zanabazar/SAGITTAL/SAG069.TIF
# Processing image #116: ../../Zanabazar/SAGITTAL/SAG068.TIF
# Processing image #117: ../../Zanabazar/SAGITTAL/SAG067.TIF
# Processing image #118: ../../Zanabazar/SAGITTAL/SAG066.TIF
# Processing image #119: ../../Zanabazar/SAGITTAL/SAG065.TIF
# Processing image #120: ../../Zanabazar/SAGITTAL/SAG064.TIF
# Processing image #121: ../../Zanabazar/SAGITTAL/SAG063.TIF
# Processing image #122: ../../Zanabazar/SAGITTAL/SAG062.TIF
# Processing image #123: ../../Zanabazar/SAGITTAL/SAG061.TIF
# Processing image #124: ../../Zanabazar/SAGITTAL/SAG060.TIF
# Processing image #125: ../../Zanabazar/SAGITTAL/SAG059.TIF
# Processing image #126: ../../Zanabazar/SAGITTAL/SAG058.TIF
# Processing image #127: ../../Zanabazar/SAGITTAL/SAG057.TIF
# Processing image #128: ../../Zanabazar/SAGITTAL/SAG056.TIF
# Processing image #129: ../../Zanabazar/SAGITTAL/SAG055.TIF
# Processing image #130: ../../Zanabazar/SAGITTAL/SAG054.TIF
# Processing image #131: ../../Zanabazar/SAGITTAL/SAG053.TIF
# Processing image #132: ../../Zanabazar/SAGITTAL/SAG052.TIF
# Processing image #133: ../../Zanabazar/SAGITTAL/SAG051.TIF
# Processing image #134: ../../Zanabazar/SAGITTAL/SAG050.TIF
# Processing image #135: ../../Zanabazar/SAGITTAL/SAG049.TIF
# Processing image #136: ../../Zanabazar/SAGITTAL/SAG048.TIF
# Processing image #137: ../../Zanabazar/SAGITTAL/SAG047.TIF
# Processing image #138: ../../Zanabazar/SAGITTAL/SAG046.TIF
# Processing image #139: ../../Zanabazar/SAGITTAL/SAG045.TIF
# Processing image #140: ../../Zanabazar/SAGITTAL/SAG044.TIF
# Processing image #141: ../../Zanabazar/SAGITTAL/SAG043.TIF
# Processing image #142: ../../Zanabazar/SAGITTAL/SAG042.TIF
# Processing image #143: ../../Zanabazar/SAGITTAL/SAG041.TIF
# Processing image #144: ../../Zanabazar/SAGITTAL/SAG040.TIF
# Processing image #145: ../../Zanabazar/SAGITTAL/SAG039.TIF
# Processing image #146: ../../Zanabazar/SAGITTAL/SAG038.TIF
# Processing image #147: ../../Zanabazar/SAGITTAL/SAG037.TIF
# Processing image #148: ../../Zanabazar/SAGITTAL/SAG036.TIF
# Processing image #149: ../../Zanabazar/SAGITTAL/SAG035.TIF
# Processing image #150: ../../Zanabazar/SAGITTAL/SAG034.TIF
# Processing image #151: ../../Zanabazar/SAGITTAL/SAG033.TIF
# Processing image #152: ../../Zanabazar/SAGITTAL/SAG032.TIF
# Processing image #153: ../../Zanabazar/SAGITTAL/SAG031.TIF
# Processing image #154: ../../Zanabazar/SAGITTAL/SAG030.TIF
# Processing image #155: ../../Zanabazar/SAGITTAL/SAG029.TIF
# Processing image #156: ../../Zanabazar/SAGITTAL/SAG028.TIF
# Processing image #157: ../../Zanabazar/SAGITTAL/SAG027.TIF
# Processing image #158: ../../Zanabazar/SAGITTAL/SAG026.TIF
# Processing image #159: ../../Zanabazar/SAGITTAL/SAG025.TIF
# Processing image #160: ../../Zanabazar/SAGITTAL/SAG024.TIF
# Processing image #161: ../../Zanabazar/SAGITTAL/SAG023.TIF
# Processing image #162: ../../Zanabazar/SAGITTAL/SAG022.TIF
# Processing image #163: ../../Zanabazar/SAGITTAL/SAG021.TIF
# Processing image #164: ../../Zanabazar/SAGITTAL/SAG020.TIF
# Processing image #165: ../../Zanabazar/SAGITTAL/SAG019.TIF
# Processing image #166: ../../Zanabazar/SAGITTAL/SAG018.TIF
# Processing image #167: ../../Zanabazar/SAGITTAL/SAG017.TIF
# Processing image #168: ../../Zanabazar/SAGITTAL/SAG016.TIF
# Processing image #169: ../../Zanabazar/SAGITTAL/SAG015.TIF
# Processing image #170: ../../Zanabazar/SAGITTAL/SAG014.TIF
# Processing image #171: ../../Zanabazar/SAGITTAL/SAG013.TIF
# Processing image #172: ../../Zanabazar/SAGITTAL/SAG012.TIF
# Processing image #173: ../../Zanabazar/SAGITTAL/SAG011.TIF
# Processing image #174: ../../Zanabazar/SAGITTAL/SAG010.TIF
# Processing image #175: ../../Zanabazar/SAGITTAL/SAG009.TIF
# Processing image #176: ../../Zanabazar/SAGITTAL/SAG008.TIF
# Processing image #177: ../../Zanabazar/SAGITTAL/SAG007.TIF
# Processing image #178: ../../Zanabazar/SAGITTAL/SAG006.TIF
# Processing image #179: ../../Zanabazar/SAGITTAL/SAG005.TIF
# Processing image #180: ../../Zanabazar/SAGITTAL/SAG004.TIF
# Processing image #181: ../../Zanabazar/SAGITTAL/SAG003.TIF
# Processing image #182: ../../Zanabazar/SAGITTAL/SAG002.TIF
# Processing image #183: ../../Zanabazar/SAGITTAL/SAG001.TIF
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-20a53e179295> in <module>()
#      43
#      44 background.show();
# ---> 45 background.save("posterior zbar.png", "PNG");
#
# //anaconda/lib/python2.7/site-packages/PIL/Image.pyc in save(self, fp, format, **params)
#    1663
#    1664         try:
# -> 1665             save_handler(self, fp, filename)
#    1666         finally:
#    1667             # do what we can to clean up
#
# //anaconda/lib/python2.7/site-packages/PIL/PngImagePlugin.pyc in _save(im, fp, filename, chunk, check)
#     755         # Compressed profile    n bytes (zlib with deflate compression)
#     756         name = b"ICC Profile"
# --> 757         data = name + b"\0\0" + zlib.compress(im.info["icc_profile"])
#     758         chunk(fp, b"iCCP", data)
#     759
#
# TypeError: must be string or read-only buffer, not tuple
