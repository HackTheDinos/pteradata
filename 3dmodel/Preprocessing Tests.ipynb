# %%
# %pwd
# Out:
# '/Users/rspeare/Documents/dinos/stacked_skulls'

# %%
from skimage import data, io, filters,feature
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.ndimage
import os

# %%
data=np.load('Zanabazar_cor.npy')

# %%
X=data[:,:,529]
bil=filters.restoration.denoise_bilateral(X)

# %%
plt.figure(figsize=(8,8))
ax1=plt.subplot2grid((2,2),(0,0))
ax1.imshow(bil)
ax2=plt.subplot2grid((2,2),(0,1))
ax2.imshow(X)
ax3=plt.subplot2grid((2,2),(1,0))
ax3.imshow((190 < X) *X * ( X < 250))
plt.show()

# %%
plt.imshow((180 < X) *X * ( X < 225))

# %%
plt.hist(data.ravel())
plt.show()

# %%
plt.imshow(X>250)
