# %%
# %pwd
# Out:
# u'/Users/nbartzokas/Desktop/pteradata/3dmodel'

# %%
from skimage import data, io, filters,feature
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy.ndimage
import os
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk
from skimage.filters.rank import median
from skimage.morphology import disk

# %%
data=np.load('zbar_cor.npy')

# %%
X=data[:,:,529]
bil=filters.restoration.denoise_bilateral(X)

# %%
plt.figure(figsize=(8,8))
ax1=plt.subplot2grid((2,2),(0,0))
ax1.imshow(bil)
ax2=plt.subplot2grid((2,2),(0,1))
ax2.imshow(X)
ax3=plt.subplot2grid((2,2),(1,0))
ax3.imshow((175 < X) *X * ( X < 250))

for i in np.arange(175,175):
    img = (i < X) *X * ( X < 250)
    opened = opening(img, disk(2))

ax4=plt.subplot2grid((2,2),(1,1))
ax4.imshow(opened)

plt.show()

# %%
plt.imshow((180 < X) *X * ( X < 225))

# %%
plt.hist(data.ravel())
plt.show()

# %%
plt.imshow(X>250)
